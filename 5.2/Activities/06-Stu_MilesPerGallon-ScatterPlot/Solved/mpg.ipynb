# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv('../Resources/mpg.csv')
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print(car_data['car name'].unique())
# Out:
# ['chevrolet chevelle malibu' 'buick skylark 320' 'plymouth satellite'
#  'amc rebel sst' 'ford torino' 'ford galaxie 500' 'chevrolet impala'
#  'plymouth fury iii' 'pontiac catalina' 'amc ambassador dpl'
#  'dodge challenger se' "plymouth 'cuda 340" 'chevrolet monte carlo'
#  'buick estate wagon (sw)' 'toyota corona mark ii' 'plymouth duster'
#  'amc hornet' 'ford maverick' 'datsun pl510'
#  'volkswagen 1131 deluxe sedan' 'peugeot 504' 'audi 100 ls' 'saab 99e'
#  'bmw 2002' 'amc gremlin' 'ford f250' 'chevy c20' 'dodge d200' 'hi 1200d'
#  'chevrolet vega 2300' 'toyota corona' 'ford pinto'
#  'plymouth satellite custom' 'ford torino 500' 'amc matador'
#  'pontiac catalina brougham' 'dodge monaco (sw)'
#  'ford country squire (sw)' 'pontiac safari (sw)'
#  'amc hornet sportabout (sw)' 'chevrolet vega (sw)' 'pontiac firebird'
#  'ford mustang' 'mercury capri 2000' 'opel 1900' 'peugeot 304' 'fiat 124b'
#  'toyota corolla 1200' 'datsun 1200' 'volkswagen model 111'
# ...

# %%
# Remove the rows with missing values in horsepower
car_data = car_data.loc[car_data['horsepower'] != "?" ]
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
car_data = car_data.loc[car_data['car name'] == "amc hornet" ]
car_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jeanp\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'car name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9308\424806951.py in <module>
# ...

# %%
# Set the 'car name' as our index
car_data = car_data.set_index('car name')

# Remove the 'origin' column
del car_data['origin']

car_data.head()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# car name
# amc hornet  18.0          6         199.0         97    2774          15.5
# amc hornet  18.0          6         232.0        100    2945          16.0
# amc hornet  19.0          6         232.0        100    2901          16.0
# amc hornet  22.5          6         232.0         90    3085          17.6
#
#             model year
# car name
# amc hornet          70
# amc hornet          73
# amc hornet          74
# amc hornet          76

# %%
print(car_data['horsepower'].dtypes)
# Out:
# object

# %%
# Convert the "horsepower" column to numeric so the data can be used
car_data['horsepower'] = pd.to_numeric(car_data['horsepower'])
print(car_data['horsepower'].dtypes)
# Out:
# int64

# %%
# Create a scatter plot which compares MPG to horsepower
car_data.plot(kind="scatter", x="horsepower", y="mpg", grid=True, figsize=(8,8),
              title="MPG Vs. Horsepower")
plt.show()
