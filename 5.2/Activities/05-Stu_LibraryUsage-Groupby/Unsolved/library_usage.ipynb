# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Library Usage
#
# For this assignment, you will be taking Library Usage data from San Francisco and creating charts to determine which patron type checks out items from the library the most.
#
# * Import your dependencies and then import your data into a pandas data frame from the CSV within the 'Data' folder
# * Reduce the data to include only patrons who have checked out at least one item
# * Split up your data into groups based upon the 'Patron Type Definition' column
# * Chart your data using a bar graph, giving it both a title and labels for the axes

# %%
library_usage_data = pd.read_csv("../Resources/library_usage.csv")
library_usage_data.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# 0                     None                    None                      z
# 1                    April                    2016                      z
# 2                     None                    None                      a
# 3                     None                    None                      z
# 4                  January                    2016                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        email                    True
# 1                        email                    True
# 2                        print                   False
# 3                        email                    True
# 4                        email                    True
#
#    Year Patron Registered  Outside of County  Supervisor District
# 0                    2014              False                  5.0
# 1                    2010              False                  4.0
# 2                    2016               True                  NaN
# 3                    2015              False                  3.0
# 4                    2003              False                  2.0

# %%
bytype = library_usage_data.groupby("Patron Type Definition").count()
print(bytype)
# Out:
#                         Patron Type Code  Total Checkouts  Total Renewals  \
# Patron Type Definition
# ADULT                             110078           110078          110078
# AT USER ADULT                        153              153             153
# AT USER JUVENILE                       1                1               1
# AT USER SENIOR                         9                9               9
# AT USER TEEN                           3                3               3
# AT USER WELCOME                       19               19              19
# BOOKS BY MAIL                         22               22              22
# DIGITAL ACCESS CARD                  704              704             704
# FRIENDS FOR LIFE                      10               10              10
# JUVENILE                              95               95              95
# RETIRED STAFF                         33               33              33
# SENIOR                             11876            11876           11876
# SPECIAL                              209              209             209
# STAFF                                174              174             174
# TEACHER CARD                         708              708             708
# VISITOR                              161              161             161
# WELCOME                             6118             6118            6118
# YOUNG ADULT                           11               11              11
#
#                         Age Range  Home Library Code  Home Library Definition  \
# Patron Type Definition
# ADULT                      110010             110071                   110078
# AT USER ADULT                 153                153                      153
# AT USER JUVENILE                1                  1                        1
# AT USER SENIOR                  9                  9                        9
# AT USER TEEN                    3                  3                        3
# AT USER WELCOME                19                 19                       19
# BOOKS BY MAIL                  21                 22                       22
# DIGITAL ACCESS CARD           703                704                      704
# FRIENDS FOR LIFE               10                 10                       10
# JUVENILE                       80                 95                       95
# RETIRED STAFF                  33                 33                       33
# SENIOR                      11869              11873                    11876
# SPECIAL                       209                209                      209
# STAFF                         174                174                      174
# TEACHER CARD                  706                708                      708
# VISITOR                       161                161                      161
# WELCOME                      6112               6118                     6118
# YOUNG ADULT                     9                 11                       11
#
#                         Circulation Active Month  Circulation Active Year  \
# Patron Type Definition
# ADULT                                     110078                   110078
# AT USER ADULT                                153                      153
# AT USER JUVENILE                               1                        1
# AT USER SENIOR                                 9                        9
# AT USER TEEN                                   3                        3
# AT USER WELCOME                               19                       19
# BOOKS BY MAIL                                 22                       22
# DIGITAL ACCESS CARD                          704                      704
# FRIENDS FOR LIFE                              10                       10
# JUVENILE                                      95                       95
# RETIRED STAFF                                 33                       33
# SENIOR                                     11876                    11876
# SPECIAL                                      209                      209
# STAFF                                        174                      174
# TEACHER CARD                                 708                      708
# VISITOR                                      161                      161
# WELCOME                                     6118                     6118
# YOUNG ADULT                                   11                       11
#
#                         Notice Preference Code  Notice Preference Definition  \
# Patron Type Definition
# ADULT                                   110078                        110078
# AT USER ADULT                              153                           153
# AT USER JUVENILE                             1                             1
# AT USER SENIOR                               9                             9
# AT USER TEEN                                 3                             3
# AT USER WELCOME                             19                            19
# BOOKS BY MAIL                               22                            22
# DIGITAL ACCESS CARD                        704                           704
# FRIENDS FOR LIFE                            10                            10
# JUVENILE                                    95                            95
# RETIRED STAFF                               33                            33
# SENIOR                                   11876                         11876
# SPECIAL                                    209                           209
# STAFF                                      174                           174
# TEACHER CARD                               708                           708
# VISITOR                                    161                           161
# WELCOME                                   6118                          6118
# YOUNG ADULT                                 11                            11
#
#                         Provided Email Address  Year Patron Registered  \
# Patron Type Definition
# ADULT                                   110078                  110078
# AT USER ADULT                              153                     153
# AT USER JUVENILE                             1                       1
# AT USER SENIOR                               9                       9
# AT USER TEEN                                 3                       3
# AT USER WELCOME                             19                      19
# BOOKS BY MAIL                               22                      22
# DIGITAL ACCESS CARD                        704                     704
# FRIENDS FOR LIFE                            10                      10
# JUVENILE                                    95                      95
# RETIRED STAFF                               33                      33
# SENIOR                                   11876                   11876
# SPECIAL                                    209                     209
# STAFF                                      174                     174
# TEACHER CARD                               708                     708
# VISITOR                                    161                     161
# WELCOME                                   6118                    6118
# YOUNG ADULT                                 11                      11
#
#                         Outside of County  Supervisor District
# Patron Type Definition
# ADULT                              110078                80373
# AT USER ADULT                         153                  104
# AT USER JUVENILE                        1                    1
# AT USER SENIOR                          9                    6
# AT USER TEEN                            3                    2
# AT USER WELCOME                        19                   13
# BOOKS BY MAIL                          22                   19
# DIGITAL ACCESS CARD                   704                  343
# FRIENDS FOR LIFE                       10                    9
# JUVENILE                               95                   72
# RETIRED STAFF                          33                   19
# SENIOR                              11876                 8656
# SPECIAL                               209                  149
# STAFF                                 174                   56
# TEACHER CARD                          708                  500
# VISITOR                               161                   88
# WELCOME                              6118                 3831
# YOUNG ADULT                            11                    6

# %% [markdown]
# # Bonus!
#
# You will now take the same base data frame before and create some code that will allow you to create individual pie charts for each library branch. For this part of the activity, we want you to chart the total 'Total Checkouts' of each library, sorted by patron type. If you are able to, try and come up with a method to do this without using loc or iloc to filter the original data frame! You can use loc to filter group data though.
#
# Since there are quite a lot of patron types with minimal checkouts, the pie charts could look messy with overlapping text. You may also like to include a filter to limit the minimum number of total checkouts by patron group.
