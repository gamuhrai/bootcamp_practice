# %%
import pandas as pd

# %%
# The path to our CSV file
file = "Resources/CrowdfundingData.csv"

# Read our Crowdfunding data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#    id                         name  \
# 0   0   Baldwin, Riley and Jackson
# 1   1                     Odom Inc
# 2   2   Melton, Robinson and Fritz
# 3   3  Mcdonald, Gonzalez and Ross
# 4   4                Larson-Little
#
#                                            blurb    goal  pledged     outcome  \
# 0           Pre-emptive tertiary standardization     100        0      failed
# 1               Managed bottom-line architecture    1400    14560  successful
# 2   Function-based leadingedge pricing structure  108400   142523  successful
# 3  Vision-oriented fresh-thinking conglomeration    4200     2477      failed
# 4                      Proactive foreground core    7600     5265      failed
#
#    backers_count country currency  launched_at    deadline  staff_pick  \
# 0              0      CA      CAD   1448690400  1450159200       False
# 1            158      US      USD   1408424400  1408597200       False
# 2           1425      AU      AUD   1384668000  1384840800       False
# 3             24      US      USD   1565499600  1568955600       False
# 4             53      US      USD   1547964000  1548309600       False
#
#    spotlight          category
# 0      False  food/food trucks
# 1       True        music/rock
# 2      False    technology/web
# 3      False        music/rock
# 4      False     theater/plays

# %%
# Get a list of all of our columns for easy reference
df.columns
# Out:
# Index(['id', 'name', 'blurb', 'goal', 'pledged', 'outcome', 'backers_count',
#        'country', 'currency', 'launched_at', 'deadline', 'staff_pick',
#        'spotlight', 'category'],
#       dtype='object')

# %%
# Extract "name", "goal", "pledged", "outcome", "country", "staff_pick",
# "backers_count", and "spotlight"

reduced_crowdfunding_df = df.loc[:,["name", "goal", "pledged", "outcome", "country", "staff_pick", "backers_count", "spotlight"]]
reduced_crowdfunding_df
# Out:
#                              name    goal  pledged     outcome country  \
# 0      Baldwin, Riley and Jackson     100        0      failed      CA
# 1                        Odom Inc    1400    14560  successful      US
# 2      Melton, Robinson and Fritz  108400   142523  successful      AU
# 3     Mcdonald, Gonzalez and Ross    4200     2477      failed      US
# 4                   Larson-Little    7600     5265      failed      US
# ..                            ...     ...      ...         ...     ...
# 995              Manning-Hamilton   97300   153216  successful      US
# 996                    Butler LLC    6600     4814      failed      US
# 997                      Ball LLC    7600     4603    canceled      IT
# 998   Taylor, Santiago and Flores   66600    37823      failed      US
# 999  Hernandez, Norton and Kelley  111100    62819    canceled      US
#
#      staff_pick  backers_count  spotlight
# 0         False              0      False
# 1         False            158       True
# 2         False           1425      False
# 3         False             24      False
# 4         False             53      False
# ..          ...            ...        ...
# 995       False           2043       True
# 996       False            112      False
# 997       False            139      False
# 998       False            374       True
# 999       False           1122      False
#
# [1000 rows x 8 columns]

# %%
# Remove projects that made no money at all
reduced_crowdfunding_df = reduced_crowdfunding_df.loc[reduced_crowdfunding_df["pledged"] > 0]
reduced_crowdfunding_df
# Out:
#   File "C:\Users\jeanp\AppData\Local\Temp\ipykernel_8844\4154326878.py", line 3
#     reduced_crowdfunding_df.
#                             ^
# SyntaxError: invalid syntax

# %%
# Collect only those projects that were hosted in the US
# Create a list of the columns

columns = ["name", "goal", "pledged", "outcome", "staff_pick", "backers_count", "spotlight"]


# Create a new df for "US" with the columns above. 

us_crowdfunding_df = reduced_crowdfunding_df.loc[reduced_crowdfunding_df["country"] == "US", columns]
us_crowdfunding_df.head()
# Out:
#                            name  goal  pledged     outcome  staff_pick  \
# 1                      Odom Inc  1400    14560  successful       False
# 3   Mcdonald, Gonzalez and Ross  4200     2477      failed       False
# 4                 Larson-Little  7600     5265      failed       False
# 9        Rangel, Holt and Jones  6200     3208      failed       False
# 10                    Green Ltd  5200    13838  successful       False
#
#     backers_count  spotlight
# 1             158       True
# 3              24      False
# 4              53      False
# 9              44      False
# 10            220      False

# %%
# Create a new column that finds the average amount pledged to a project

us_crowdfunding_df["average_donation"] = us_crowdfunding_df["pledged"] / us_crowdfunding_df["backers_count"]
us_crowdfunding_df.head()
# Out:
#                            name  goal  pledged     outcome  staff_pick  \
# 1                      Odom Inc  1400    14560  successful       False
# 3   Mcdonald, Gonzalez and Ross  4200     2477      failed       False
# 4                 Larson-Little  7600     5265      failed       False
# 9        Rangel, Holt and Jones  6200     3208      failed       False
# 10                    Green Ltd  5200    13838  successful       False
#
#     backers_count  spotlight  average_donation
# 1             158       True         92.151899
# 3              24      False        103.208333
# 4              53      False         99.339623
# 9              44      False         72.909091
# 10            220      False         62.900000

# %%
# First convert "average_donation", "goal", and "pledged" columns to float
# Then Format to go to two decimal places, include a dollar sign, and use comma notation

us_crowdfunding_df["average_donation"] = us_crowdfunding_df["average_donation"].map("${:,.2f}".format)
us_crowdfunding_df["goal"] = us_crowdfunding_df["goal"].map("${:,.2f}".format)
us_crowdfunding_df["pledged"] = us_crowdfunding_df["pledged"].map("${:,.2f}".format)

# %%
us_crowdfunding_df.head()
# Out:
#                            name       goal     pledged     outcome  \
# 1                      Odom Inc  $1,400.00  $14,560.00  successful
# 3   Mcdonald, Gonzalez and Ross  $4,200.00   $2,477.00      failed
# 4                 Larson-Little  $7,600.00   $5,265.00      failed
# 9        Rangel, Holt and Jones  $6,200.00   $3,208.00      failed
# 10                    Green Ltd  $5,200.00  $13,838.00  successful
#
#     staff_pick  backers_count  spotlight average_donation
# 1        False            158       True           $92.15
# 3        False             24      False          $103.21
# 4        False             53      False           $99.34
# 9        False             44      False           $72.91
# 10       False            220      False           $62.90

# %%
# Calculate the total number of backers for all US projects
us_crowdfunding_df["backers_count"].sum()
# Out:
# 545510

# %%
# Calculate the average number of backers for all US projects
us_crowdfunding_df["backers_count"].mean()
# Out:
# 715.8923884514436

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"

staff_picks_df = us_crowdfunding_df.loc[us_crowdfunding_df["staff_pick"] == True]
staff_picks_df.head()
# Out:
#                           name         goal     pledged     outcome  \
# 76   Martin, Conway and Larsen  $122,900.00  $95,993.00      failed
# 86                 Davis-Smith    $7,400.00  $12,405.00  successful
# 193   Calhoun, Rogers and Long    $6,600.00   $3,012.00      failed
# 205             Weaver-Marquez    $1,300.00   $5,614.00  successful
# 220                   Owens-Le    $7,900.00     $667.00      failed
#
#      staff_pick  backers_count  spotlight average_donation
# 76         True           1684       True           $57.00
# 86         True            203      False           $61.11
# 193        True             65      False           $46.34
# 205        True             80      False           $70.17
# 220        True             17      False           $39.24

# %%
# Group by the outcome of the campaigns and see if staff picks matter (Seems to matter quite a bit)

stackpick_groups = staff_picks_df.groupby("outcome")
print(stackpick_groups["name"].count())
# Out:
# outcome
# canceled       3
# failed        13
# successful    23
# Name: name, dtype: int64
