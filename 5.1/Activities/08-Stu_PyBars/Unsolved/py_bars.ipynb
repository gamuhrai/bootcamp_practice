# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["San Francisco", "Omaha", "New Orleans", "Cincinnati", "Pittsburgh"]
cars_in_cities = [214.7, 564.4, 416.5, 466.7, 350.6]
x_axis = np.arange(len(cars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,cars_in_cities,color='blue',alpha=0.25, align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x1b071d6a380>,
#   <matplotlib.axis.XTick at 0x1b071d6a770>,
#   <matplotlib.axis.XTick at 0x1b071d6a530>,
#   <matplotlib.axis.XTick at 0x1b071d96d10>,
#   <matplotlib.axis.XTick at 0x1b071d97460>],
#  [Text(0, 0, 'San Francisco'),
#   Text(1, 0, 'Omaha'),
#   Text(2, 0, 'New Orleans'),
#   Text(3, 0, 'Cincinnati'),
#   Text(4, 0, 'Pittsburgh')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(cars_in_cities)+50)
# Out:
# (0.0, 614.4)

# %%
# Give the chart a title, x label, and y label
# # Give our chart some labels and a tile
plt.title("Popularity of Programming Languages")
plt.xlabel("Cities")
plt.ylabel("Number of Cars in Cities")
plt.show()

# %%
# Save an image of the chart and print it to the screen
