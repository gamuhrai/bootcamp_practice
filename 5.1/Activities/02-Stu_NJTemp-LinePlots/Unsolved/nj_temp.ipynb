# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nj_temp = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]
nj_temp_month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"]

# %%
# Create a graph based upon the list and array we have created
plt.plot(nj_temp_month, nj_temp)
# Show the graph that we have created
plt.show()

# %%
def f_to_c(x):
    return (x-32)*.56

# %%
c_nj_temp = np.array([f_to_c(temp) for temp in nj_temp_month])
# Create a graph based upon the list and array we have created
plt.plot(nj_temp_month, c_nj_temp)
# Show the graph that we have created
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c_nj_temp = np.array([f_to_c(temp) for temp in nj_temp_month])
#       2 # Create a graph based upon the list and array we have created
#       3 plt.plot(nj_temp_month, c_nj_temp)
#
# Cell In[14], line 1, in <listcomp>(.0)
# ----> 1 c_nj_temp = np.array([f_to_c(temp) for temp in nj_temp_month])
#       2 # Create a graph based upon the list and array we have created
#       3 plt.plot(nj_temp_month, c_nj_temp)
#
# Cell In[12], line 2, in f_to_c(x)
#       1 def f_to_c(x):
# ----> 2     return (x-32)*.56
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
